# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandhini3Devaraj/data-analysis-course/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=[
  {
    "name": "Arjun",
    "age": 21,
    "gender": "Male",
    "dept": "CSE",
    "genderid": 1,
    "cgpa": 8.7,
    "placed": "Yes",
    "student_id": "S101"
  },
  {
    "name": "Meena",
    "age": 22,
    "gender": "Female",
    "dept": "AIDS",
    "genderid": 2,
    "cgpa": 9.1,
    "placed": "Yes",
    "student_id": "S102"
  },
  {
    "name": "Ravi",
    "age": 21,
    "gender": "Male",
    "dept": "ECE",
    "genderid": 1,
    "cgpa": 7.8,
    "placed": "No",
    "student_id": "S103"
  },
  {
    "name": "Priya",
    "age": 23,
    "gender": "Female",
    "dept": "IT",
    "genderid": 2,
    "cgpa": 8.4,
    "placed": "Yes",
    "student_id": "S104"
  },
  {
    "name": "Karthik",
    "age": 22,
    "gender": "Male",
    "dept": "CSE",
    "genderid": 1,
    "cgpa": 7.5,
    "placed": "No",
    "student_id": "S105"
  }
]

# %%
import pandas as pd
df=pd.DataFrame(data)
print(df)
# Out:
#       name  age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun   21    Male   CSE         1   8.7    Yes       S101
# 1    Meena   22  Female  AIDS         2   9.1    Yes       S102
# 2     Ravi   21    Male   ECE         1   7.8     No       S103
# 3    Priya   23  Female    IT         2   8.4    Yes       S104
# 4  Karthik   22    Male   CSE         1   7.5     No       S105

# %%
df.isnull()
# Out:
#     name    age  gender   dept  genderid   cgpa  placed  student_id
# 0  False  False   False  False     False  False   False       False
# 1  False  False   False  False     False  False   False       False
# 2  False  False   False  False     False  False   False       False
# 3  False  False   False  False     False  False   False       False
# 4  False  False   False  False     False  False   False       False

# %%
data=[
  {
    "name": "Arjun",
    "age": 21,
    "gender": "Male",
    "dept": "CSE",
    "genderid": 1,
    "cgpa": 8.7,
    "placed": "Yes",
    "student_id": "S101"
  },
  {
    "name": "Meena",
    "age": None,
    "gender": "Female",
    "dept": "AIDS",
    "genderid": 2,
    "cgpa": 9.1,
    "placed": "Yes",
    "student_id": "S102"
  },
  {
    "name": "Ravi",
    "age": 21,
    "gender": None,
    "dept": "ECE",
    "genderid": None,
    "cgpa": 7.8,
    "placed": "No",
    "student_id": "S103"
  },
  {
    "name": "Priya",
    "age": 23,
    "gender": "Female",
    "dept": None,
    "genderid": 2,
    "cgpa": None,
    "placed": "Yes",
    "student_id": "S104"
  },
  {
    "name": 'riya',
    "age": 22,
    "gender": "Male",
    "dept": "CSE",
    "genderid": 1,
    "cgpa": 7.5,
    "placed": None,
    "student_id": "S105"
  },
  {
    "name": "Karthik",
    "age": 22,
    "gender": "Male",
    "dept": "IT",
    "genderid": 1,
    "cgpa": 8.0,
    "placed": "Yes",
    "student_id": "S106"
  },
  {
    "name": "Divya",
    "age": 21,
    "gender": "Female",
    "dept": "CSE",
    "genderid": 2,
    "cgpa": None,
    "placed": "No",
    "student_id": "S107"
  },
  {
    "name": "Rahul",
    "age": None,
    "gender": "Male",
    "dept": "ECE",
    "genderid": 1,
    "cgpa": 6.9,
    "placed": "No",
    "student_id": "S108"
  },
  {
    "name": "Sneha",
    "age": 23,
    "gender": "Female",
    "dept": "AIDS",
    "genderid": 2,
    "cgpa": 8.6,
    "placed": None,
    "student_id": "S109"
  },
  {
    "name": "Vikram",
    "age": 24,
    "gender": "Male",
    "dept": None,
    "genderid": 1,
    "cgpa": 7.2,
    "placed": "Yes",
    "student_id": "S110"
  }
]
import pandas as pd
df=pd.DataFrame(data)
print(df)
# Out:
#       name   age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.0    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena   NaN  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.0    None   ECE       NaN   7.8     No       S103
# 3    Priya  23.0  Female  None       2.0   NaN    Yes       S104
# 4     riya  22.0    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.0    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.0  Female   CSE       2.0   NaN     No       S107
# 7    Rahul   NaN    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.0  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.0    Male  None       1.0   7.2    Yes       S110

# %%
import numpy as np
df = df.replace({None: np.nan})

# %%
print(df)
# Out:
#       name   age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.0    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena   NaN  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.0     NaN   ECE       NaN   7.8     No       S103
# 3    Priya  23.0  Female   NaN       2.0   NaN    Yes       S104
# 4      NaN  22.0    Male   CSE       1.0   7.5    NaN       S105
# 5  Karthik  22.0    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.0  Female   CSE       2.0   NaN     No       S107
# 7    Rahul   NaN    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.0  Female  AIDS       2.0   8.6    NaN       S109
# 9   Vikram  24.0    Male   NaN       1.0   7.2    Yes       S110

# %%
df.isnull()
# Out:
#     name    age  gender   dept  genderid   cgpa  placed  student_id
# 0  False  False   False  False     False  False   False       False
# 1  False   True   False  False     False  False   False       False
# 2  False  False    True  False      True  False   False       False
# 3  False  False   False   True     False   True   False       False
# 4   True  False   False  False     False  False    True       False
# 5  False  False   False  False     False  False   False       False
# 6  False  False   False  False     False   True   False       False
# 7  False   True   False  False     False  False   False       False
# 8  False  False   False  False     False  False    True       False
# 9  False  False   False   True     False  False   False       False

# %%
print(df.isnull().sum())
# Out:
# name          1
# age           2
# gender        1
# dept          2
# genderid      1
# cgpa          2
# placed        2
# student_id    0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# select only numeric columns
num_cols = df.select_dtypes(include=['number'])

# normalize
df[num_cols.columns] = scaler.fit_transform(num_cols)

print(df)
# Out:
#       name       age  gender  dept  genderid      cgpa placed student_id
# 0    Arjun -1.068103    Male   CSE -0.894427  1.001191    Yes       S101
# 1    Meena       NaN  Female  AIDS  1.118034  1.553573    Yes       S102
# 2     Ravi -1.068103     NaN   ECE       NaN -0.241667     No       S103
# 3    Priya  0.830747  Female   NaN  1.118034       NaN    Yes       S104
# 4      NaN -0.118678    Male   CSE -0.894427 -0.655953    NaN       S105
# 5  Karthik -0.118678    Male    IT -0.894427  0.034524    Yes       S106
# 6    Divya -1.068103  Female   CSE  1.118034       NaN     No       S107
# 7    Rahul       NaN    Male   ECE -0.894427 -1.484525     No       S108
# 8    Sneha  0.830747  Female  AIDS  1.118034  0.863096    NaN       S109
# 9   Vikram  1.780172    Male   NaN -0.894427 -1.070239    Yes       S110

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_698/1503503937.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %%
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    None   ECE       NaN   7.8     No       S103
# 3    Priya  23.000  Female  None       2.0   NaN    Yes       S104
# 4     None  22.000    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   NaN     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.000    Male  None       1.0   7.2    Yes       S110

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_698/1503503937.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %%
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    None   ECE       NaN   7.8     No       S103
# 3    Priya  23.000  Female  None       2.0   NaN    Yes       S104
# 4     riya  22.000    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   NaN     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.000    Male  None       1.0   7.2    Yes       S110

# %%
df['gender'].fillna(df['gender'].mode()[0], inplace=True)

# %%
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    Male   ECE       NaN   7.8     No       S103
# 3    Priya  23.000  Female  None       2.0   NaN    Yes       S104
# 4     riya  22.000    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   NaN     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.000    Male  None       1.0   7.2    Yes       S110

# %%
df['dept'].fillna(df['dept'].mode()[0], inplace=True)

# %%
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    Male   ECE       NaN   7.8     No       S103
# 3    Priya  23.000  Female   CSE       2.0   NaN    Yes       S104
# 4     riya  22.000    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   NaN     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.000    Male   CSE       1.0   7.2    Yes       S110

# %%
df['genderid'].fillna(df['genderid'].mode()[0], inplace=True)
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    Male   ECE       1.0   7.8     No       S103
# 3    Priya  23.000  Female   CSE       2.0   NaN    Yes       S104
# 4     riya  22.000    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   NaN     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.000    Male   CSE       1.0   7.2    Yes       S110
# /tmp/ipykernel_698/1340098603.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['cgpa'].fillna(df['cgpa'].mode()[0], inplace=True)
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    Male   ECE       1.0   7.8     No       S103
# 3    Priya  23.000  Female   CSE       2.0   6.9    Yes       S104
# 4     riya  22.000    Male   CSE       1.0   7.5   None       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   6.9     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6   None       S109
# 9   Vikram  24.000    Male   CSE       1.0   7.2    Yes       S110
# /tmp/ipykernel_698/3870721684.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['placed'].fillna(df['placed'].mode()[0], inplace=True)
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000    Male   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125  Female  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000    Male   ECE       1.0   7.8     No       S103
# 3    Priya  23.000  Female   CSE       2.0   6.9    Yes       S104
# 4     riya  22.000    Male   CSE       1.0   7.5    Yes       S105
# 5  Karthik  22.000    Male    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000  Female   CSE       2.0   6.9     No       S107
# 7    Rahul  22.125    Male   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000  Female  AIDS       2.0   8.6    Yes       S109
# 9   Vikram  24.000    Male   CSE       1.0   7.2    Yes       S110
# /tmp/ipykernel_698/2950201301.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['gender']=le.fit_transform(df["gender"])
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa placed student_id
# 0    Arjun  21.000       1   CSE       1.0   8.7    Yes       S101
# 1    Meena  22.125       0  AIDS       2.0   9.1    Yes       S102
# 2     Ravi  21.000       1   ECE       1.0   7.8     No       S103
# 3    Priya  23.000       0   CSE       2.0   6.9    Yes       S104
# 4     riya  22.000       1   CSE       1.0   7.5    Yes       S105
# 5  Karthik  22.000       1    IT       1.0   8.0    Yes       S106
# 6    Divya  21.000       0   CSE       2.0   6.9     No       S107
# 7    Rahul  22.125       1   ECE       1.0   6.9     No       S108
# 8    Sneha  23.000       0  AIDS       2.0   8.6    Yes       S109
# 9   Vikram  24.000       1   CSE       1.0   7.2    Yes       S110

# %%
df['placed']=le.fit_transform(df["placed"])
print(df)
# Out:
#       name     age  gender  dept  genderid  cgpa  placed student_id
# 0    Arjun  21.000       1   CSE       1.0   8.7       1       S101
# 1    Meena  22.125       0  AIDS       2.0   9.1       1       S102
# 2     Ravi  21.000       1   ECE       1.0   7.8       0       S103
# 3    Priya  23.000       0   CSE       2.0   6.9       1       S104
# 4     riya  22.000       1   CSE       1.0   7.5       1       S105
# 5  Karthik  22.000       1    IT       1.0   8.0       1       S106
# 6    Divya  21.000       0   CSE       2.0   6.9       0       S107
# 7    Rahul  22.125       1   ECE       1.0   6.9       0       S108
# 8    Sneha  23.000       0  AIDS       2.0   8.6       1       S109
# 9   Vikram  24.000       1   CSE       1.0   7.2       1       S110

# %%
df[['age', 'cgpa']]
# Out:
#       age  cgpa
# 0  21.000   8.7
# 1  22.125   9.1
# 2  21.000   7.8
# 3  23.000   6.9
# 4  22.000   7.5
# 5  22.000   8.0
# 6  21.000   6.9
# 7  22.125   6.9
# 8  23.000   8.6
# 9  24.000   7.2

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['age', 'cgpa']] = scaler.fit_transform(df[['age', 'cgpa']])
print(df)
# Out:
#       name       age  gender  dept  genderid      cgpa  placed student_id
# 0    Arjun -1.194176       1   CSE       1.0  1.209109       1       S101
# 1    Meena  0.000000       0  AIDS       2.0  1.723624       1       S102
# 2     Ravi -1.194176       1   ECE       1.0  0.051451       0       S103
# 3    Priya  0.928804       0   CSE       2.0 -1.106207       1       S104
# 4     riya -0.132686       1   CSE       1.0 -0.334435       1       S105
# 5  Karthik -0.132686       1    IT       1.0  0.308709       1       S106
# 6    Divya -1.194176       0   CSE       2.0 -1.106207       0       S107
# 7    Rahul  0.000000       1   ECE       1.0 -1.106207       0       S108
# 8    Sneha  0.928804       0  AIDS       2.0  1.080481       1       S109
# 9   Vikram  1.990293       1   CSE       1.0 -0.720321       1       S110
